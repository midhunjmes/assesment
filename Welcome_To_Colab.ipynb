# %% [markdown]
# <a href="https://colab.research.google.com/github/midhunjmes/assesment/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Automated Code Documentation Generate clear documentation from code snippets Create function descriptions and parameter explanations Implement usage examples based on function signatures Evaluate documentation quality and technical accuracy

# %%
pip install groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 2.7 MB/s eta 0:00:00
# ...

# %%
import os
from groq import Groq


os.environ["GROQ_API_KEY"] = "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"


client = Groq(api_key=os.environ.get("GROQ_API_KEY"))

def read_python_file(file_path):
    """Read the content of a Python file."""
    with open(file_path, 'r') as file:
        return file.read()

def generate_documentation(code_content):
    """Generate documentation for the given Python code content."""
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": f"Generate documentation for the following Python code:\n\n{code_content}",
            }
        ],
        model="llama-3.3-70b-versatile",
    )
    return chat_completion.choices[0].message.content

def main():
    python_file_path = "/content/inheritence.py"


    code_content = read_python_file(python_file_path)

    documentation = generate_documentation(code_content)

    print("Generated Documentation:\n")
    print(documentation)

if __name__ == "__main__":
    main()
# Out:
# Generated Documentation:
#
# ## Car Classes Documentation
# ### Introduction
# This module contains three classes: `ElectricCar`, `FuelCar`, and `HybridCar`. These classes represent different types of vehicles and provide methods for common vehicle operations.
#
# ### Classes
# #### ElectricCar
#  Represents an electric car with a battery.
#
# ##### Attributes
# * `battery_capacity`: The capacity of the car's battery in kWh.
#
# ##### Methods
# * `__init__(battery_capacity)`: Initializes an `ElectricCar` object with the given `battery_capacity`.
# * `charge_battery()`: Returns a message indicating that the battery has been charged to its full capacity.
#
# ##### Example
# ```python
# electric = ElectricCar(battery_capacity=40)
# print(electric.charge_battery())  # Output: Battery charged to 40 kWh.
# ```
#
# #### FuelCar
#  Represents a fuel-powered car with a fuel tank.
#
# ##### Attributes
# * `fuel_capacity`: The capacity of the car's fuel tank in liters.
#
# ##### Methods
# ...

# %%
import ast
import os
from groq import Groq


os.environ["GROQ_API_KEY"] = "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"

client = Groq(api_key=os.environ.get("GROQ_API_KEY"))

def read_python_file(file_path):
    """Read the content of a Python file."""
    with open(file_path, 'r') as file:
        return file.read()

def extract_functions(code_content):
    """Extract function definitions from Python code."""
    functions = []
    tree = ast.parse(code_content)
    for node in ast.walk(tree):
        if isinstance(node, ast.FunctionDef):
            functions.append({
                "name": node.name,
                "args": [arg.arg for arg in node.args.args],
                "docstring": ast.get_docstring(node),
            })
    return functions

def generate_documentation(function_info):
    """Generate documentation for a function using Groq API."""
    prompt = (
        f"Generate clear documentation for the following Python function:\n\n"
        f"Function Name: {function_info['name']}\n"
        f"Parameters: {', '.join(function_info['args'])}\n"
        f"Docstring: {function_info['docstring']}\n\n"
        f"Provide:\n"
        f"1. A detailed description of the function.\n"
        f"2. Explanation of each parameter.\n"
        f"3. A usage example based on the function signature.\n"
    )
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": prompt,
            }
        ],
        model="llama-3.3-70b-versatile",
    )
    return chat_completion.choices[0].message.content

def evaluate_documentation_quality(documentation):
    """Evaluate the quality of the generated documentation."""
    prompt = (
        f"Evaluate the quality and technical accuracy of the following Python function documentation:\n\n"
        f"{documentation}\n\n"
        f"Provide feedback on:\n"
        f"1. Clarity and readability.\n"
        f"2. Completeness of parameter explanations.\n"
        f"3. Correctness of the usage example.\n"
    )
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": prompt,
            }
        ],
        model="llama-3.3-70b-versatile",
    )
    return chat_completion.choices[0].message.content

def main():

    python_file_path = "/content/inheritence.py"


    code_content = read_python_file(python_file_path)


    functions = extract_functions(code_content)


    for func in functions:
        print(f"\n=== Function: {func['name']} ===")


        documentation = generate_documentation(func)
        print("\nGenerated Documentation:\n")
        print(documentation)

        evaluation = evaluate_documentation_quality(documentation)
        print("\nDocumentation Evaluation:\n")
        print(evaluation)

if __name__ == "__main__":
    main()
# Out:
# === Function: __init__ ===
#
# Generated Documentation:
#
# ## `__init__` Function Documentation
# ### Description
#
# The `__init__` function is a special method in Python classes, known as a constructor. This function is automatically called when an object of the class is instantiated. In this specific implementation, the `__init__` function initializes an object with a specified `battery_capacity`. This suggests that the class is likely designed to represent a device or entity that has a battery, such as an electric vehicle, a smartphone, or any other battery-powered device.
#
# ### Parameters
#
# * **`self`**: This is a reference to the current instance of the class and is used to access variables and methods from the class. It is passed automatically when the method is called, so it does not need to be explicitly provided when calling the method.
# ...

# %% [markdown]
# openai

# %% [markdown]
# gemma2-9b-it

# %%
import ast
import os
from groq import Groq

# Set your Groq API key
os.environ["GROQ_API_KEY"] = "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"

# Initialize the Groq client
client = Groq(api_key=os.environ.get("GROQ_API_KEY"))

def read_python_file(file_path):
    """Read the content of a Python file."""
    with open(file_path, 'r') as file:
        return file.read()

def extract_functions(code_content):
    """Extract function definitions from Python code."""
    functions = []
    tree = ast.parse(code_content)
    for node in ast.walk(tree):
        if isinstance(node, ast.FunctionDef):
            functions.append({
                "name": node.name,
                "args": [arg.arg for arg in node.args.args],
                "docstring": ast.get_docstring(node),
            })
    return functions

def generate_documentation(function_info):
    """Generate documentation for a function using Groq API."""
    prompt = (
        f"Generate clear documentation for the following Python function:\n\n"
        f"Function Name: {function_info['name']}\n"
        f"Parameters: {', '.join(function_info['args'])}\n"
        f"Docstring: {function_info['docstring']}\n\n"
        f"Provide:\n"
        f"1. A detailed description of the function.\n"
        f"2. Explanation of each parameter.\n"
        f"3. A usage example based on the function signature.\n"
    )
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": prompt,
            }
        ],
        model="gemma2-9b-it",
    )
    return chat_completion.choices[0].message.content

def evaluate_documentation_quality(documentation):
    """Evaluate the quality of the generated documentation."""
    prompt = (
        f"Evaluate the quality and technical accuracy of the following Python function documentation:\n\n"
        f"{documentation}\n\n"
        f"Provide feedback on:\n"
        f"1. Clarity and readability.\n"
        f"2. Completeness of parameter explanations.\n"
        f"3. Correctness of the usage example.\n"
    )
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": prompt,
            }
        ],
        model="gemma2-9b-it",
    )
    return chat_completion.choices[0].message.content

def main():
    # Specify the path to your Python file
    python_file_path = "/content/inheritence.py"  # Replace with your Python file path

    # Read the content of the Python file
    code_content = read_python_file(python_file_path)

    # Extract functions from the code
    functions = extract_functions(code_content)

    # Generate and evaluate documentation for each function
    for func in functions:
        print(f"\n=== Function: {func['name']} ===")

        # Generate documentation
        documentation = generate_documentation(func)
        print("\nGenerated Documentation:\n")
        print(documentation)

        # Evaluate documentation quality
        evaluation = evaluate_documentation_quality(documentation)
        print("\nDocumentation Evaluation:\n")
        print(evaluation)

if __name__ == "__main__":
    main()
# Out:
# === Function: __init__ ===
#
# Generated Documentation:
#
# ```python
# def __init__(self, battery_capacity):
#   """Initializes Battery object with a given capacity."""
#   self.battery_capacity = battery_capacity
# ```
#
# **Detailed Description:**
#
# The `__init__` function is a special method in Python, known as the constructor. It is automatically called when a new object of the class is created. This function initializes the object's attributes, setting its initial state.
#
# In the context of a Battery object, the `__init__` function takes the battery's capacity as input and stores it as an attribute of the object. This allows each Battery object to be uniquely defined by its capacity.
#
# **Parameter Explanation:**
#
# 1. **self:** This parameter is a reference to the instance of the class being created. It allows the function to access and modify the object's attributes.
#
# ...

# %%
import ast
import os
from groq import Groq


os.environ["GROQ_API_KEY"] = "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"

client = Groq(api_key=os.environ.get("GROQ_API_KEY"))

def read_python_file(file_path):
    """Read the content of a Python file."""
    with open(file_path, 'r') as file:
        return file.read()

def extract_functions(code_content):
    """Extract function definitions from Python code."""
    functions = []
    tree = ast.parse(code_content)
    for node in ast.walk(tree):
        if isinstance(node, ast.FunctionDef):
            functions.append({
                "name": node.name,
                "args": [arg.arg for arg in node.args.args],
                "docstring": ast.get_docstring(node),
            })
    return functions

def generate_documentation(function_info):
    """Generate documentation for a function using Groq API."""
    prompt = (
    f"Generate comprehensive documentation for the following Python function:\n\n"
    f"Function Name: {function_info['name']}\n"
    f"Parameters: {', '.join(function_info['args'])}\n"
    f"Docstring: {function_info['docstring']}\n\n"
    f"Include:\n"
    f"- A brief description of the function.\n"
    f"- Explanation of each parameter and avoid example use cases.\n"
)

    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": prompt,
            }
        ],
        model="mixtral-8x7b-32768",
        #max_tokens=500,
    )
    return chat_completion.choices[0].message.content

def evaluate_documentation_quality(documentation):
    """Evaluate the quality of the generated documentation."""
    prompt = (
    f"Review the following Python function documentation for clarity and accuracy:\n\n"
    f"{documentation}\n\n"
    f"Provide brief feedback on clarity, completeness, and correctness.\n"
)

    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": prompt,
            }
        ],
        model="mixtral-8x7b-32768",
    )
    return chat_completion.choices[0].message.content

# %%
    python_file_path = "/content/inheritence.py"


    code_content = read_python_file(python_file_path)


    functions = extract_functions(code_content)


    for func in functions:
        print(f"\n=== Function: {func['name']} ===")


        documentation = generate_documentation(func)
        print("\nGenerated Documentation:\n")
        print(documentation)
# Out:
# === Function: __init__ ===
#
# Generated Documentation:
#
# Function Name: **init**
#
# Brief Description:
# The **init** function is a special method in Python classes, which is used for initializing new object instances. It allows you to assign initial values to an object's attributes, and prepare the object for use.
#
# Parameters:
#
# 1. self:
#    - Description: The `self` parameter is a conventional name for the first parameter of a method. It's a reference to the current instance of the class and is used to access variables that belong to the class.
#    - Type: `object` (implicit)
#    - Default Value: None
#    - Usage: The `self` parameter is automatically passed as the first argument when calling a method on an object.
#
# 2. battery\_capacity:
#    - Description: `battery_capacity` is an input parameter indicating the initial battery capacity of an object.
#    - Type: `integer` or `float`
#    - Default Value: None
# ...

# %%
documentation = generate_documentation(func)
evaluation = evaluate_documentation_quality(documentation)

print("\nDocumentation Evaluation:\n")
print(evaluation)
# Out:
# Documentation Evaluation:
#
# The documentation for the `show_info` function is clear, complete, and correct. It explains the purpose of the function, provides an example usage, and defines the parameter. Here are some minor suggestions to improve clarity:
#
# * In the "Example Usage" section, you may want to explicitly mention that `show_info` is an instance method of the `MyClass` class. This can help readers understand that they need to create an instance of the class before calling the method.
# * In the "Parameters" section, you may want to mention that `self` is a conventionally named parameter and not a reserved keyword. This will help readers understand that they can use a different name for the first parameter of an instance method if they prefer.
# ...
